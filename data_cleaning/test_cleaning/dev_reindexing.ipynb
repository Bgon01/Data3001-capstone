# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functools import lru_cache

@lru_cache(maxsize=None)  
def fetch_data_from_source(parquet_file):
    df = pd.read_parquet(f"https://data3001-racing.s3.ap-southeast-2.amazonaws.com/{parquet_file}")
    return df

def fetch_data_csv(parquet_file):
    df = pd.read_csv(f"https://data3001-racing.s3.ap-southeast-2.amazonaws.com/{parquet_file}")
    return df

# %%
df = fetch_data_from_source('f1sim-data-2022.parquet')

# %%
df["TEMP_SESSION_IDENTIFIER"] = df["SESSION_IDENTIFIER"].astype(str)
df["TEMP_LAP_NUM"] = df["LAP_NUM"].astype(str)

# %%
df["TEMP_INDEX"] = df["TEMP_SESSION_IDENTIFIER"]+df["TEMP_LAP_NUM"]

# %%
df["LAP_INDEX"] = df["TEMP_INDEX"].rank(method='dense').astype(int)

# %%
df = df.drop('TEMP_INDEX', axis=1)
df = df.drop('TEMP_SESSION_IDENTIFIER', axis=1)
df = df.drop('TEMP_LAP_NUM', axis=1)

# %%
df = df[['LAP_INDEX', 'SESSION_IDENTIFIER', 'FRAME', 'LAP_NUM', 'SECTOR', 'LAP_DISTANCE',
       'CURRENT_LAP_TIME_MS', 'SECTOR_1_TIME_MS', 'SECTOR_2_TIME_MS',
       'LAP_TIME_MS', 'SECTOR_3_MS', 'SPEED_KPH', 'THROTTLE', 'BRAKE', 'GEAR',
       'ENGINE_RPM', 'STEERING', 'YAW', 'PITCH', 'ROLL', 'WORLDPOSX',
       'WORLDPOSY', 'WORLDPOSZ', 'WORLDFORWARDDIRX', 'WORLDFORWARDDIRY',
       'WORLDFORWARDDIRZ', 'WORLDRIGHTDIRX', 'WORLDRIGHTDIRY',
       'WORLDRIGHTDIRZ']]

# %%
df
# Out:
#          LAP_INDEX  SESSION_IDENTIFIER  FRAME  LAP_NUM  SECTOR  LAP_DISTANCE  \
# 0             1046        5.892042e+16    756        1       1      0.790606
# 1             1046        5.892042e+16    757        1       1      4.920292
# 2             1046        5.892042e+16    758        1       1     10.424754
# 3             1046        5.892042e+16    759        1       1     14.567660
# 4             1046        5.892042e+16    760        1       1     20.093290
# ...            ...                 ...    ...      ...     ...           ...
# 1851295        739        1.843892e+19  12607        2       3   5214.656250
# 1851296        739        1.843892e+19  12615        2       3   5223.962891
# 1851297        739        1.843892e+19  12617        2       3   5226.138672
# 1851298        739        1.843892e+19  12622        2       3   5231.236328
# 1851299        739        1.843892e+19  12630        2       3   5240.841797
#
#          CURRENT_LAP_TIME_MS  SECTOR_1_TIME_MS  SECTOR_2_TIME_MS  LAP_TIME_MS  \
# 0                          0             31444             19019      87429.0
# 1                         50             31444             19019      87429.0
# 2                        116             31444             19019      87429.0
# 3                        166             31444             19019      87429.0
# 4                        233             31444             19019      87429.0
# ...                      ...               ...               ...          ...
# 1851295               183948              5592             48163     185332.0
# 1851296               184165              5592             48163     185332.0
# 1851297               184215              5592             48163     185332.0
# 1851298               184332              5592             48163     185332.0
# 1851299               184549              5592             48163     185332.0
#
#          ...      ROLL   WORLDPOSX   WORLDPOSY  WORLDPOSZ  WORLDFORWARDDIRX  \
# 0        ... -0.025697  112.275528  465.772919   2.916000          -23844.0
# 1        ... -0.026746  115.282364  462.940033   2.894297          -23821.0
# 2        ... -0.025638  119.286469  459.159943   2.851826          -23793.0
# 3        ... -0.025774  122.297539  456.312012   2.826670          -23777.0
# 4        ... -0.025487  126.310883  452.510620   2.798397          -23767.0
# ...      ...       ...         ...         ...        ...               ...
# 1851295  ... -0.019106   66.070663  508.290283   3.266118          -24709.0
# 1851296  ... -0.022962   72.955887  502.024353   3.218785          -23692.0
# 1851297  ... -0.021950   74.527908  500.519928   3.200713          -23488.0
# 1851298  ... -0.021773   78.164688  496.942932   3.160474          -23122.0
# 1851299  ... -0.020095   84.846382  490.024994   3.134241          -22318.0
#
#          WORLDFORWARDDIRY  WORLDFORWARDDIRZ  WORLDRIGHTDIRX  WORLDRIGHTDIRY  \
# 0                  -134.0          -22474.0         22464.0           841.0
# 1                  -195.0          -22498.0         22487.0           876.0
# 2                  -201.0          -22528.0         22517.0           839.0
# 3                  -178.0          -22545.0         22534.0           844.0
# 4                  -130.0          -22555.0         22545.0           835.0
# ...                   ...               ...             ...             ...
# 1851295            -215.0          -21518.0         21512.0           625.0
# 1851296            -254.0          -22633.0         22624.0           752.0
# 1851297            -298.0          -22844.0         22835.0           719.0
# 1851298            -152.0          -23216.0         23208.0           713.0
# 1851299             -84.0          -23990.0         23984.0           658.0
#
#          WORLDRIGHTDIRZ
# 0              -23839.0
# 1              -23816.0
# 2              -23789.0
# 3              -23772.0
# 4              -23762.0
# ...                 ...
# 1851295        -24708.0
# 1851296        -23690.0
# 1851297        -23488.0
# 1851298        -23119.0
# 1851299        -22315.0
#
# [1851300 rows x 29 columns]
