# %% [markdown]
# This aims to see if every xy pair of coordinates correlates to a particular z value, i.e. seeing if porpoising etc. have an effect in our case.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from functools import lru_cache

# %%
@lru_cache(maxsize=None)  
def fetch_data_from_source(parquet_file):
    df = pd.read_parquet(f"https://data3001-racing.s3.ap-southeast-2.amazonaws.com/{parquet_file}")
    return df

def fetch_data_csv(parquet_file):
    df = pd.read_csv(f"https://data3001-racing.s3.ap-southeast-2.amazonaws.com/{parquet_file}")
    return df

# %%
# Inputs: N/A
# Outputs: df with both datasets appended to each other (sorted by "SESSION_IDENTIFIER" then "FRAME")
# NOTE: 'SECTOR' has been changed from {0,1,2} to {1,2,3}

def fetch_and_merge():
    df22 = fetch_data_from_source('f1sim-data-2022.parquet')
    df23 = fetch_data_from_source('f1sim-data-2023.parquet')
    df = pd.concat([df22, df23], ignore_index=True)
    df.dropna(inplace=True)
    df.sort_values(by=["SESSION_IDENTIFIER", "FRAME"], inplace=True)
    df.reset_index(drop=True, inplace=True)
    df["SECTOR"] = df["SECTOR"] + 1
    return df

# %%
turns_df = fetch_data_csv('f1sim-ref-turns.csv')
left_df = fetch_data_csv('f1sim-ref-left.csv')
right_df = fetch_data_csv('f1sim-ref-right.csv')
line_df = fetch_data_csv('f1sim-ref-line.csv')

# %%
df = fetch_and_merge()

# %%
df
# Out:
#          SESSION_IDENTIFIER  FRAME  LAP_NUM  SECTOR  LAP_DISTANCE  \
# 0              5.892042e+16    756        1       1      0.790606
# 1              5.892042e+16    757        1       1      4.920292
# 2              5.892042e+16    758        1       1     10.424754
# 3              5.892042e+16    759        1       1     14.567660
# 4              5.892042e+16    760        1       1     20.093290
# ...                     ...    ...      ...     ...           ...
# 1851295        1.843892e+19  12607        2       3   5214.656250
# 1851296        1.843892e+19  12615        2       3   5223.962891
# 1851297        1.843892e+19  12617        2       3   5226.138672
# 1851298        1.843892e+19  12622        2       3   5231.236328
# 1851299        1.843892e+19  12630        2       3   5240.841797
#
#          CURRENT_LAP_TIME_MS  SECTOR_1_TIME_MS  SECTOR_2_TIME_MS  LAP_TIME_MS  \
# 0                          0             31444             19019      87429.0
# 1                         50             31444             19019      87429.0
# 2                        116             31444             19019      87429.0
# 3                        166             31444             19019      87429.0
# 4                        233             31444             19019      87429.0
# ...                      ...               ...               ...          ...
# 1851295               183948              5592             48163     185332.0
# 1851296               184165              5592             48163     185332.0
# 1851297               184215              5592             48163     185332.0
# 1851298               184332              5592             48163     185332.0
# 1851299               184549              5592             48163     185332.0
#
#          SECTOR_3_MS  ...      ROLL   WORLDPOSX   WORLDPOSY  WORLDPOSZ  \
# 0            36966.0  ... -0.025697  112.275528  465.772919   2.916000
# 1            36966.0  ... -0.026746  115.282364  462.940033   2.894297
# 2            36966.0  ... -0.025638  119.286469  459.159943   2.851826
# 3            36966.0  ... -0.025774  122.297539  456.312012   2.826670
# 4            36966.0  ... -0.025487  126.310883  452.510620   2.798397
# ...              ...  ...       ...         ...         ...        ...
# 1851295     131577.0  ... -0.019106   66.070663  508.290283   3.266118
# 1851296     131577.0  ... -0.022962   72.955887  502.024353   3.218785
# 1851297     131577.0  ... -0.021950   74.527908  500.519928   3.200713
# 1851298     131577.0  ... -0.021773   78.164688  496.942932   3.160474
# 1851299     131577.0  ... -0.020095   84.846382  490.024994   3.134241
#
#          WORLDFORWARDDIRX  WORLDFORWARDDIRY  WORLDFORWARDDIRZ  WORLDRIGHTDIRX  \
# 0                -23844.0            -134.0          -22474.0         22464.0
# 1                -23821.0            -195.0          -22498.0         22487.0
# 2                -23793.0            -201.0          -22528.0         22517.0
# 3                -23777.0            -178.0          -22545.0         22534.0
# 4                -23767.0            -130.0          -22555.0         22545.0
# ...                   ...               ...               ...             ...
# 1851295          -24709.0            -215.0          -21518.0         21512.0
# 1851296          -23692.0            -254.0          -22633.0         22624.0
# 1851297          -23488.0            -298.0          -22844.0         22835.0
# 1851298          -23122.0            -152.0          -23216.0         23208.0
# 1851299          -22318.0             -84.0          -23990.0         23984.0
#
#          WORLDRIGHTDIRY  WORLDRIGHTDIRZ
# 0                 841.0        -23839.0
# 1                 876.0        -23816.0
# 2                 839.0        -23789.0
# 3                 844.0        -23772.0
# 4                 835.0        -23762.0
# ...                 ...             ...
# 1851295           625.0        -24708.0
# 1851296           752.0        -23690.0
# 1851297           719.0        -23488.0
# 1851298           713.0        -23119.0
# 1851299           658.0        -22315.0
#
# [1851300 rows x 28 columns]
